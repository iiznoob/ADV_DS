# %% [markdown]
# <h4>Lab No 3</h4>
# <h4 align="right"> Utkarsh Bhangale<br>2020802124</h4>

# %% [markdown]
# # Problem On Feature encoding, scaling and selection.

# %% [markdown]
# Aim: The objective of this lab assignment is to gain a deep understanding of various techniques
# for feature encoding, scaling, and selection in the context of data preprocessing for machine
# learning.

# %% [markdown]
# Task-1: Data Preparation

# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_wine

wine = load_wine()
wine_data = wine.data
wine_target = wine.target


df = pd.DataFrame(wine_data, columns = wine.feature_names)
df['target'] = wine_target
df.head(10)
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
# 5    14.20        1.76  2.45               15.2      112.0           3.27
# 6    14.39        1.87  2.45               14.6       96.0           2.50
# 7    14.06        2.15  2.61               17.6      121.0           2.60
# 8    14.83        1.64  2.17               14.0       97.0           2.80
# 9    13.86        1.35  2.27               16.0       98.0           2.98
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# ...

# %%
df.shape
# Out:
# (178, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   alcohol                       178 non-null    float64
#  1   malic_acid                    178 non-null    float64
#  2   ash                           178 non-null    float64
#  3   alcalinity_of_ash             178 non-null    float64
#  4   magnesium                     178 non-null    float64
#  5   total_phenols                 178 non-null    float64
#  6   flavanoids                    178 non-null    float64
#  7   nonflavanoid_phenols          178 non-null    float64
#  8   proanthocyanins               178 non-null    float64
#  9   color_intensity               178 non-null    float64
#  10  hue                           178 non-null    float64
#  11  od280/od315_of_diluted_wines  178 non-null    float64
# ...

# %%
df.describe()
# Out:
#           alcohol  malic_acid         ash  alcalinity_of_ash   magnesium  \
# count  178.000000  178.000000  178.000000         178.000000  178.000000
# mean    13.000618    2.336348    2.366517          19.494944   99.741573
# std      0.811827    1.117146    0.274344           3.339564   14.282484
# min     11.030000    0.740000    1.360000          10.600000   70.000000
# 25%     12.362500    1.602500    2.210000          17.200000   88.000000
# 50%     13.050000    1.865000    2.360000          19.500000   98.000000
# 75%     13.677500    3.082500    2.557500          21.500000  107.000000
# max     14.830000    5.800000    3.230000          30.000000  162.000000
#
#        total_phenols  flavanoids  nonflavanoid_phenols  proanthocyanins  \
# count     178.000000  178.000000            178.000000       178.000000
# mean        2.295112    2.029270              0.361854         1.590899
# std         0.625851    0.998859              0.124453         0.572359
# ...

# %% [markdown]
# basic statistical analysis

# %%
import numpy as np
from google.colab import autoviz

def histogram(df, colname, num_bins=20, figscale=1):
  from matplotlib import pyplot as plt
  df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
  plt.gca().spines[['top', 'right',]].set_visible(False)
  plt.tight_layout()
  return autoviz.MplChart.from_current_mpl_state()

chart = histogram(_df_16, *['alcohol'], **{})
chart
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-221862b2db69> in <cell line: 11>()
#       9   return autoviz.MplChart.from_current_mpl_state()
#      10
# ---> 11 chart = histogram(_df_16, *['alcohol'], **{})
#      12 chart
#
# NameError: name '_df_16' is not defined

# %%
import numpy as np
from google.colab import autoviz

def histogram(df, colname, num_bins=20, figscale=1):
  from matplotlib import pyplot as plt
  df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
  plt.gca().spines[['top', 'right',]].set_visible(False)
  plt.tight_layout()
  return autoviz.MplChart.from_current_mpl_state()

chart = histogram(_df_17, *['malic_acid'], **{})
chart

# %%
import numpy as np
from google.colab import autoviz

def histogram(df, colname, num_bins=20, figscale=1):
  from matplotlib import pyplot as plt
  df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
  plt.gca().spines[['top', 'right',]].set_visible(False)
  plt.tight_layout()
  return autoviz.MplChart.from_current_mpl_state()

chart = histogram(_df_18, *['ash'], **{})
chart
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-02528ab06dde> in <cell line: 11>()
#       9   return autoviz.MplChart.from_current_mpl_state()
#      10
# ---> 11 chart = histogram(_df_18, *['ash'], **{})
#      12 chart
#
# NameError: name '_df_18' is not defined

# %%
import numpy as np
from google.colab import autoviz

def histogram(df, colname, num_bins=20, figscale=1):
  from matplotlib import pyplot as plt
  df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
  plt.gca().spines[['top', 'right',]].set_visible(False)
  plt.tight_layout()
  return autoviz.MplChart.from_current_mpl_state()

chart = histogram(_df_19, *['alcalinity_of_ash'], **{})
chart
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-adc339c66f7e> in <cell line: 11>()
#       9   return autoviz.MplChart.from_current_mpl_state()
#      10
# ---> 11 chart = histogram(_df_19, *['alcalinity_of_ash'], **{})
#      12 chart
#
# NameError: name '_df_19' is not defined

# %% [markdown]
# Task-2: Feature Encoding

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

df['target'] = le.fit_transform(df['target'])
df.head()
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline  target
# ...

# %% [markdown]
# encoding

# %%
from sklearn.preprocessing import OneHotEncoder

ohe = OneHotEncoder(handle_unknown='ignore')

ohe_df = pd.DataFrame(ohe.fit_transform(df[['target']]).toarray())
X = df.join(ohe_df)  #X'e ekledik
X.drop('target', axis=1, inplace=True) # nom0 kaldırdık

X.head(3)
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
#
#    od280/od315_of_diluted_wines  proline    0    1    2
# 0                          3.92   1065.0  1.0  0.0  0.0
# 1                          3.40   1050.0  1.0  0.0  0.0
# 2                          3.17   1185.0  1.0  0.0  0.0

# %% [markdown]
# Task-3: Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaled_data = scaler.fit_transform(df)
scaled_data
# Out:
# array([[ 1.51861254, -0.5622498 ,  0.23205254, ...,  1.84791957,
#          1.01300893, -1.21394365],
#        [ 0.24628963, -0.49941338, -0.82799632, ...,  1.1134493 ,
#          0.96524152, -1.21394365],
#        [ 0.19687903,  0.02123125,  1.10933436, ...,  0.78858745,
#          1.39514818, -1.21394365],
#        ...,
#        [ 0.33275817,  1.74474449, -0.38935541, ..., -1.48544548,
#          0.28057537,  1.37386437],
#        [ 0.20923168,  0.22769377,  0.01273209, ..., -1.40069891,
#          0.29649784,  1.37386437],
#        [ 1.39508604,  1.58316512,  1.36520822, ..., -1.42894777,
#         -0.59516041,  1.37386437]])

# %% [markdown]
# Task-4: Feature Selection

# %%
from sklearn.feature_selection import RFECV
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rfecv = RFECV(estimator=rf, step=1)

rfecv.fit(scaled_data, df['target'])

print(rfecv.support_)

print(rfecv.ranking_)
# Out:
# [False False False False False False False False False False False False
#  False  True]
# [ 6  9 13 11 12  8  4 14 10  2  7  5  3  1]

# %% [markdown]
# Task-5: Model Building and Evaluation

# %%
from sklearn.model_selection import train_test_split

from sklearn.metrics import accuracy_score


X_train, X_test, y_train, y_test = train_test_split(df, df['target'])



from sklearn.linear_model import LogisticRegression

logmodel = LogisticRegression().fit(X_train, y_train)

predictions = logmodel.predict(X_test)

print('Accuracy: ', accuracy_score(y_test, predictions))
# Out:
# Accuracy:  0.9555555555555556
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# Conclusion:-
# Successfully completed all the tasks with Accuracy of 95% for the model
